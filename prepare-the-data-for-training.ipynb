# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import glob as gb
import cv2

# %%
data=pd.read_csv('./input/dfl-bundesliga-data-shootout/train.csv')

# %%
data.head()
# Out:
#      video_id        time      event           event_attributes
# 0  1606b0e6_0  200.265822      start                        NaN
# 1  1606b0e6_0  201.150000  challenge     ['ball_action_forced']
# 2  1606b0e6_0  202.765822        end                        NaN
# 3  1606b0e6_0  210.124111      start                        NaN
# 4  1606b0e6_0  210.870000  challenge  ['opponent_dispossessed']

# %%
data.drop(['event_attributes'],inplace=True,axis=1)

# %%
data.head()
# Out:
#      video_id        time      event
# 0  1606b0e6_0  200.265822      start
# 1  1606b0e6_0  201.150000  challenge
# 2  1606b0e6_0  202.765822        end
# 3  1606b0e6_0  210.124111      start
# 4  1606b0e6_0  210.870000  challenge

# %%
data_challenge=data[data['event']=='challenge']

# %%
data_challenge.head()
# Out:
#       video_id    time      event
# 1   1606b0e6_0  201.15  challenge
# 4   1606b0e6_0  210.87  challenge
# 59  1606b0e6_0  300.99  challenge
# 62  1606b0e6_0  307.27  challenge
# 79  1606b0e6_0  395.55  challenge

# %%
data_challenge.shape
# Out:
# (624, 3)

# %%
data_play=data[data['event']=='play']

# %%
data_play.head()
# Out:
#       video_id    time event
# 10  1606b0e6_0  224.43  play
# 13  1606b0e6_0  229.39  play
# 16  1606b0e6_0  236.71  play
# 17  1606b0e6_0  239.35  play
# 20  1606b0e6_0  242.39  play

# %%
data_play.shape
# Out:
# (3586, 3)

# %%
data_throwin=data[data['event']=='throwin']

# %%
data_throwin.head()
# Out:
#        video_id    time    event
# 7    1606b0e6_0  219.23  throwin
# 101  1606b0e6_0  427.67  throwin
# 119  1606b0e6_0  474.39  throwin
# 162  1606b0e6_0  621.11  throwin
# 265  1606b0e6_0  875.39  throwin

# %%
data_throwin.shape
# Out:
# (172, 3)

# %%
# !pip install moviepy
# Out:
# Requirement already satisfied: moviepy in c:\users\juanc\appdata\local\programs\python\python310\lib\site-packages (1.0.3)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in c:\users\juanc\appdata\local\programs\python\python310\lib\site-packages (from moviepy) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in c:\users\juanc\appdata\local\programs\python\python310\lib\site-packages (from moviepy) (4.65.0)
# Requirement already satisfied: requests<3.0,>=2.8.1 in c:\users\juanc\appdata\local\programs\python\python310\lib\site-packages (from moviepy) (2.28.2)
# Requirement already satisfied: proglog<=1.0.0 in c:\users\juanc\appdata\local\programs\python\python310\lib\site-packages (from moviepy) (0.1.10)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\juanc\appdata\local\programs\python\python310\lib\site-packages (from moviepy) (1.23.5)
# Requirement already satisfied: imageio<3.0,>=2.5 in c:\users\juanc\appdata\local\programs\python\python310\lib\site-packages (from moviepy) (2.31.5)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in c:\users\juanc\appdata\local\programs\python\python310\lib\site-packages (from moviepy) (0.4.9)
# Requirement already satisfied: pillow>=8.3.2 in c:\users\juanc\appdata\local\programs\python\python310\lib\site-packages (from imageio<3.0,>=2.5->moviepy) (9.5.0)
# Requirement already satisfied: setuptools in c:\users\juanc\appdata\local\programs\python\python310\lib\site-packages (from imageio-ffmpeg>=0.2.0->moviepy) (60.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\juanc\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\juanc\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\juanc\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\juanc\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (2022.12.7)
# Requirement already satisfied: colorama in c:\users\juanc\appdata\local\programs\python\python310\lib\site-packages (from tqdm<5.0,>=4.11.2->moviepy) (0.4.6)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\juanc\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\juanc\appdata\local\programs\python\python310\lib\site-packages)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
os.makedirs('dataset')
os.makedirs('dataset/play')
os.makedirs('dataset/throwin')
os.makedirs('dataset/challenge')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# c:\Users\juanc\Desktop\UVG\Clases\Data_Science\Proyecto-Data-Science\prepare-the-data-for-training.ipynb Cell 16 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/juanc/Desktop/UVG/Clases/Data_Science/Proyecto-Data-Science/prepare-the-data-for-training.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> os.makedirs('dataset')
#       <a href='vscode-notebook-cell:/c%3A/Users/juanc/Desktop/UVG/Clases/Data_Science/Proyecto-Data-Science/prepare-the-data-for-training.ipynb#X21sZmlsZQ%3D%3D?line=1'>2</a> os.makedirs('dataset/play')
#       <a href='vscode-notebook-cell:/c%3A/Users/juanc/Desktop/UVG/Clases/Data_Science/Proyecto-Data-Science/prepare-the-data-for-training.ipynb#X21sZmlsZQ%3D%3D?line=2'>3</a> os.makedirs('dataset/throwin')
#
# File c:\Users\juanc\AppData\Local\Programs\Python\Python310\lib\os.py:225, in makedirs(name, mode, exist_ok)
#     223         return
#     224 try:
# --> 225     mkdir(name, mode)
#     226 except OSError:
#     227     # Cannot rely on checking for EEXIST, since the operating system
#     228     # could give priority to other errors like EACCES or EROFS
#     229     if not exist_ok or not path.isdir(name):
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'dataset'

# %%
#import shutil
#shutil.rmtree("./dataset")

# %%
play_path='./dataset/play'
throwin_path='./dataset/throwin'
challenge_path='./dataset/challenge'

# %%
from moviepy.video.io.ffmpeg_tools import ffmpeg_extract_subclip

# %%
data_throwin.shape[0]
# Out:
# 172

# %%
import time
def split_video_train(event_data,video_path,path_save_images,time_before_event,time_after_event,path_cutvideo,skip_frame):
    count=0
    skip_frames=0
    start_time=time.time()
    print('start time : ' , start_time)
    for i in range(event_data.shape[0]):
        index_video=event_data.iloc[i,0]
        index_time=event_data.iloc[i,1]
        ffmpeg_extract_subclip(f"{video_path}/{index_video}.mp4" , index_time - time_before_event, index_time + time_after_event , targetname="cutvideo.mp4")
        cap=cv2.VideoCapture(f'{path_cutvideo}/cutvideo.mp4')
        print('strart')
        while cap.isOpened() :
            ret,image=cap.read()
            if ret== False :
                break 
            if skip_frames % skip_frame == 0 :
                cv2.imwrite(f'{path_save_images}/{index_video}_{count}.jpg',image)
                count  = count + 1 
            skip_frames = skip_frames + 1
        cap.release()
        print('end')
    print('number of frames : ',count)
    print('end time : ', time.time() - start_time)

# %%
split_video_train(event_data = data_throwin
                  ,video_path = './input/dfl-bundesliga-data-shootout/train'
                  ,path_save_images = throwin_path
                  ,time_before_event = 0.1
                  ,time_after_event = 0.025
                  ,path_cutvideo = '.'
                  ,skip_frame = 3
                 )
# Out:
# start time :  1698291005.8039196
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# number of frames :  138
# end time :  157.01819515228271

# %%
split_video_train(event_data = data_challenge
                  ,video_path = './input/dfl-bundesliga-data-shootout/train'
                  ,path_save_images = challenge_path
                  ,time_before_event = 0.1
                  ,time_after_event = 0.025
                  ,path_cutvideo = '.'
                  ,skip_frame = 1
                 )
# Out:
# start time :  1698291162.8362906
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# number of frames :  5156
# end time :  717.7600138187408

# %%
split_video_train(event_data = data_play
                  ,video_path = './input/dfl-bundesliga-data-shootout/train'
                  ,path_save_images = play_path
                  ,time_before_event = 0.00
                  ,time_after_event = 0.02
                  ,path_cutvideo = '.'
                  ,skip_frame = 12
                 )
# Out:
# start time :  1698291880.6172743
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# ...
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# strart
# end
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\juanc\Desktop\UVG\Clases\Data_Science\Proyecto-Data-Science\prepare-the-data-for-training.ipynb Cell 24 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/juanc/Desktop/UVG/Clases/Data_Science/Proyecto-Data-Science/prepare-the-data-for-training.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> split_video_train(event_data = data_play
#       <a href='vscode-notebook-cell:/c%3A/Users/juanc/Desktop/UVG/Clases/Data_Science/Proyecto-Data-Science/prepare-the-data-for-training.ipynb#X32sZmlsZQ%3D%3D?line=1'>2</a>                   ,video_path = './input/dfl-bundesliga-data-shootout/train'
#       <a href='vscode-notebook-cell:/c%3A/Users/juanc/Desktop/UVG/Clases/Data_Science/Proyecto-Data-Science/prepare-the-data-for-training.ipynb#X32sZmlsZQ%3D%3D?line=2'>3</a>                   ,path_save_images = play_path
#       <a href='vscode-notebook-cell:/c%3A/Users/juanc/Desktop/UVG/Clases/Data_Science/Proyecto-Data-Science/prepare-the-data-for-training.ipynb#X32sZmlsZQ%3D%3D?line=3'>4</a>                   ,time_before_event = 0.00
#       <a href='vscode-notebook-cell:/c%3A/Users/juanc/Desktop/UVG/Clases/Data_Science/Proyecto-Data-Science/prepare-the-data-for-training.ipynb#X32sZmlsZQ%3D%3D?line=4'>5</a>                   ,time_after_event = 0.02
#       <a href='vscode-notebook-cell:/c%3A/Users/juanc/Desktop/UVG/Clases/Data_Science/Proyecto-Data-Science/prepare-the-data-for-training.ipynb#X32sZmlsZQ%3D%3D?line=5'>6</a>                   ,path_cutvideo = '.'
#       <a href='vscode-notebook-cell:/c%3A/Users/juanc/Desktop/UVG/Clases/Data_Science/Proyecto-Data-Science/prepare-the-data-for-training.ipynb#X32sZmlsZQ%3D%3D?line=6'>7</a>                   ,skip_frame = 12
#       <a href='vscode-notebook-cell:/c%3A/Users/juanc/Desktop/UVG/Clases/Data_Science/Proyecto-Data-Science/prepare-the-data-for-training.ipynb#X32sZmlsZQ%3D%3D?line=7'>8</a>                  )
#
# c:\Users\juanc\Desktop\UVG\Clases\Data_Science\Proyecto-Data-Science\prepare-the-data-for-training.ipynb Cell 24 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/juanc/Desktop/UVG/Clases/Data_Science/Proyecto-Data-Science/prepare-the-data-for-training.ipynb#X32sZmlsZQ%3D%3D?line=7'>8</a> index_video=event_data.iloc[i,0]
#       <a href='vscode-notebook-cell:/c%3A/Users/juanc/Desktop/UVG/Clases/Data_Science/Proyecto-Data-Science/prepare-the-data-for-training.ipynb#X32sZmlsZQ%3D%3D?line=8'>9</a> index_time=event_data.iloc[i,1]
# ---> <a href='vscode-notebook-cell:/c%3A/Users/juanc/Desktop/UVG/Clases/Data_Science/Proyecto-Data-Science/prepare-the-data-for-training.ipynb#X32sZmlsZQ%3D%3D?line=9'>10</a> ffmpeg_extract_subclip(f"{video_path}/{index_video}.mp4" , index_time - time_before_event, index_time + time_after_event , targetname="cutvideo.mp4")
#      <a href='vscode-notebook-cell:/c%3A/Users/juanc/Desktop/UVG/Clases/Data_Science/Proyecto-Data-Science/prepare-the-data-for-training.ipynb#X32sZmlsZQ%3D%3D?line=10'>11</a> cap=cv2.VideoCapture(f'{path_cutvideo}/cutvideo.mp4')
#      <a href='vscode-notebook-cell:/c%3A/Users/juanc/Desktop/UVG/Clases/Data_Science/Proyecto-Data-Science/prepare-the-data-for-training.ipynb#X32sZmlsZQ%3D%3D?line=11'>12</a> print('strart')
#
# File c:\Users\juanc\AppData\Local\Programs\Python\Python310\lib\site-packages\moviepy\video\io\ffmpeg_tools.py:41, in ffmpeg_extract_subclip(filename, t1, t2, targetname)
#      33     targetname = "%sSUB%d_%d.%s" % (name, T1, T2, ext)
#      35 cmd = [get_setting("FFMPEG_BINARY"),"-y",
#      36        "-ss", "%0.2f"%t1,
#      37        "-i", filename,
#      38        "-t", "%0.2f"%(t2-t1),
#      39        "-map", "0", "-vcodec", "copy", "-acodec", "copy", targetname]
# ---> 41 subprocess_call(cmd)
#
# File c:\Users\juanc\AppData\Local\Programs\Python\Python310\lib\site-packages\moviepy\tools.py:46, in subprocess_call(cmd, logger, errorprint)
#      43 if os.name == "nt":
#      44     popen_params["creationflags"] = 0x08000000
# ---> 46 proc = sp.Popen(cmd, **popen_params)
#      48 out, err = proc.communicate() # proc.wait()
#      49 proc.stderr.close()
#
# File c:\Users\juanc\AppData\Local\Programs\Python\Python310\lib\subprocess.py:971, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize)
#     967         if self.text_mode:
#     968             self.stderr = io.TextIOWrapper(self.stderr,
#     969                     encoding=encoding, errors=errors)
# --> 971     self._execute_child(args, executable, preexec_fn, close_fds,
#     972                         pass_fds, cwd, env,
#     973                         startupinfo, creationflags, shell,
#     974                         p2cread, p2cwrite,
#     975                         c2pread, c2pwrite,
#     976                         errread, errwrite,
#     977                         restore_signals,
#     978                         gid, gids, uid, umask,
#     979                         start_new_session)
#     980 except:
#     981     # Cleanup if the child failed starting.
#     982     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File c:\Users\juanc\AppData\Local\Programs\Python\Python310\lib\subprocess.py:1456, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session)
#    1454 # Start the process
#    1455 try:
# -> 1456     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1457                              # no special security
#    1458                              None, None,
#    1459                              int(not close_fds),
#    1460                              creationflags,
#    1461                              env,
#    1462                              cwd,
#    1463                              startupinfo)
#    1464 finally:
#    1465     # Child is launched. Close the parent's copy of those pipe
#    1466     # handles that only the child should have open.  You need
#    (...)
#    1469     # pipe will not close when the child process exits and the
#    1470     # ReadFile will hang.
#    1471     self._close_pipe_fds(p2cread, p2cwrite,
#    1472                          c2pread, c2pwrite,
#    1473                          errread, errwrite)
#
# KeyboardInterrupt:

# %%
# !zip -r file.zip './dataset'
# Out:
# 'zip' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from IPython.display import FileLink

# %%
FileLink(r'file.zip')
# Out:
# c:\Users\juanc\Desktop\UVG\Clases\Data_Science\Proyecto-Data-Science\file.zip
